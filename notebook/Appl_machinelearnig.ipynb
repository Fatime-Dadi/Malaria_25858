# %%
# Import libraries necessary for this project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load data
df = pd.read_csv('../cleaned_data.csv')

# %%
df.head()
# Out:
#    Case Identification  Region  Type of Place of Residence  \
# 0                 1002       2                           1
# 1                 1004       2                           1
# 2                 1007       2                           1
# 3                 1010       2                           1
# 4                 1013       2                           1
#
#    Source of Drinking Water  Type of Toilet Facility  Has Electricity  \
# 0                         7                       12                1
# 1                        12                       12                1
# 2                        13                       12                1
# 3                        13                       12                1
# 4                        12                       12                1
#
#    Main Floor Material  Main Wall Material  Main Roof Material  Has Bicycle  \
# 0                    1                   4                  13            0
# ...

# %%
df.corr()
# Out:
#                                     Case Identification    Region  \
# Case Identification                            1.000000  0.638407
# Region                                         0.638407  1.000000
# Type of Place of Residence                     0.177207  0.216471
# Source of Drinking Water                      -0.069848 -0.060153
# Type of Toilet Facility                       -0.301690 -0.148401
# Has Electricity                                0.346318  0.289698
# Main Floor Material                           -0.376437 -0.234595
# Main Wall Material                            -0.213831 -0.104933
# Main Roof Material                             0.008252  0.005104
# Has Bicycle                                   -0.146270 -0.126672
# Has Motorcycle or Scooter                     -0.065808 -0.079948
# Has Car or Truck                               0.069636  0.050033
# Has Mosquito Bed Net for Sleeping             -0.209054 -0.076900
# ...

# %%
num_obs = len(df)
num_true = len(df.loc[df['Has Mosquito Bed Net for Sleeping'] == 1])
num_false = len(df.loc[df['Has Mosquito Bed Net for Sleeping'] == 0])
print("Number of True cases:  {0} ({1:2.2f}%)".format(num_true, (num_true/num_obs) * 100))
print("Number of False cases: {0} ({1:2.2f}%)".format(num_false, (num_false/num_obs) * 100))
# Out:
# Number of True cases:  5431 (70.13%)
# Number of False cases: 2313 (29.87%)

# %%
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
feature_col_names = ['Region', 'Type of Place of Residence', 'Source of Drinking Water', 'Has Electricity', 'Wealth Index', 'Has Bicycle', 'Has Motorcycle or Scooter', 'Has Car or Truck', 'Owns Land Suitable for Agriculture', 'Has Bank Account', 'Main Floor Material', 'Main Wall Material', 'Main Roof Material']
predicted_class_names = ['Has Mosquito Bed Net for Sleeping']

X = df[feature_col_names].values     # predictor feature columns (8 X m)
y = df[predicted_class_names].values # predicted class (1=true, 0=false) column (1 X m)
split_test_size = 0.20

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_test_size, random_state=42) 
                            # test_size = 0.3 is 30%, 42 is the answer to everything

# %%
print("{0:0.2f}% in training set".format((len(X_train)/len(df.index)) * 100))
print("{0:0.2f}% in test set".format((len(X_test)/len(df.index)) * 100))
# Out:
# 80.00% in training set
# 20.00% in test set

# %%
print("Original True  : {0} ({1:0.2f}%)".format(len(df.loc[df['Has Mosquito Bed Net for Sleeping'] == 1]), (len(df.loc[df['Has Mosquito Bed Net for Sleeping'] == 1])/len(df.index)) * 100.0))
print("Original False : {0} ({1:0.2f}%)".format(len(df.loc[df['Has Mosquito Bed Net for Sleeping'] == 0]), (len(df.loc[df['Has Mosquito Bed Net for Sleeping'] == 0])/len(df.index)) * 100.0))
print("")
print("Training True  : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 1]), (len(y_train[y_train[:] == 1])/len(y_train) * 100.0)))
print("Training False : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 0]), (len(y_train[y_train[:] == 0])/len(y_train) * 100.0)))
print("")
print("Test True      : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 1]), (len(y_test[y_test[:] == 1])/len(y_test) * 100.0)))
print("Test False     : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 0]), (len(y_test[y_test[:] == 0])/len(y_test) * 100.0)))
# Out:
# Original True  : 5431 (70.13%)
# Original False : 2313 (29.87%)
#
# Training True  : 4362 (70.41%)
# Training False : 1833 (29.59%)
#
# Test True      : 1069 (69.01%)
# Test False     : 480 (30.99%)

# %%
# Training Initial Algorithm - Using Naive Bayes Machine Learning Model
from sklearn.naive_bayes import GaussianNB

# create Gaussian Naive Bayes model object and train it with the data
nb_model = GaussianNB()

nb_model.fit(X_train, y_train.ravel())
# Out:
# GaussianNB()

# %%
# predict values using the training data
nb_predict_train = nb_model.predict(X_train)

# import the performance metrics library
from sklearn import metrics

# Accuracy
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, nb_predict_train)))
print()
# Out:
# Accuracy: 0.6588

# %%
# predict values using the testing data
nb_predict_test = nb_model.predict(X_test)


# training metrics
print("nb_predict_test", nb_predict_test)
print ("y_test", y_test)
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, nb_predict_test)))
# Out:
# nb_predict_test [1 1 1 ... 1 0 1]
# y_test [[1]
#  [1]
#  [0]
#  ...
#  [1]
#  [1]
#  [0]]
# Accuracy: 0.6346

# %%
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, nb_predict_test)))
print("")

print("Classification Report")
print(metrics.classification_report(y_test, nb_predict_test))
# Out:
# Confusion Matrix
# [[195 285]
#  [281 788]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.41      0.41      0.41       480
#            1       0.73      0.74      0.74      1069
#
#     accuracy                           0.63      1549
#    macro avg       0.57      0.57      0.57      1549
# weighted avg       0.63      0.63      0.63      1549

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42, n_estimators=10)      # Create random forest object
rf_model.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
rf_predict_train = rf_model.predict(X_train)
# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, rf_predict_train)))
# Out:
# Accuracy: 0.8920

# %%
rf_predict_test = rf_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, rf_predict_test)))
# Out:
# Accuracy: 0.6507

# %%
print(metrics.confusion_matrix(y_test, rf_predict_test) )
print("")
print("Classification Report")
print(metrics.classification_report(y_test, rf_predict_test))
# Out:
# [[171 309]
#  [232 837]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.36      0.39       480
#            1       0.73      0.78      0.76      1069
#
#     accuracy                           0.65      1549
#    macro avg       0.58      0.57      0.57      1549
# weighted avg       0.64      0.65      0.64      1549

# %%
#Logistic Regression Model
from sklearn.linear_model import LogisticRegression

lr_model =LogisticRegression(C=0.7, random_state=42, solver='liblinear', max_iter=10000)
lr_model.fit(X_train, y_train.ravel())
lr_predict_test = lr_model.predict(X_test)

# training metrics
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))
print(metrics.confusion_matrix(y_test, lr_predict_test) )
print("")
print("Classification Report")
print(metrics.classification_report(y_test, lr_predict_test))
# Out:
# Accuracy: 0.6914
# [[  15  465]
#  [  13 1056]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      0.03      0.06       480
#            1       0.69      0.99      0.82      1069
#
#     accuracy                           0.69      1549
#    macro avg       0.61      0.51      0.44      1549
# weighted avg       0.65      0.69      0.58      1549
