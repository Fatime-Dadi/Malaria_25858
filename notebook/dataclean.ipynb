# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %%
# load datasets
Malaria = pd.read_csv('../Nigerian_malaria.csv')

# %%
Malaria.head(10)
# Out:
#    hhid       hv024  hv025                  hv201  \
# 0  1002  north west  urban         protected well
# 1  1004  north west  urban           tanker truck
# 2  1007  north west  urban  tube well or borehole
# 3  1010  north west  urban  tube well or borehole
# 4  1013  north west  urban           tanker truck
# 5  1016  north west  urban  tube well or borehole
# 6  1019  north west  urban  tube well or borehole
# 7  1022  north west  urban           tanker truck
# 8  1025  north west  urban           tanker truck
# 9  1027  north west  urban  tube well or borehole
#
#                                    hv205 hv206          hv213      hv214  \
# 0  ventilated improved pit latrine (vip)   yes         cement     cement
# 1  ventilated improved pit latrine (vip)   yes   palm, bamboo     cement
# 2  ventilated improved pit latrine (vip)   yes         cement     cement
# 3  ventilated improved pit latrine (vip)   yes         cement     cement
# ...

# %%
# Rename the columns : The column names in the dataset above have coded names.
#  We are going to assign human-readable names to the columns and print shape and head of the data.
Malaria.columns=['Case Identification', 'Region', 'Type of Place of Residence', 'Source of Drinking Water', 'Type of Toilet Facility',
                'Has Electricity', 'Main Floor Material', 'Main Wall Material', 'Main Roof Material', 'Has Bicycle', 'Has Motorcycle or Scooter',
                'Has Car or Truck', 'Has Mosquito Bed Net for Sleeping', 'Owns Land Suitable for Agriculture', 'Has Bank Account', 
                'Wealth Index', 'Cost of Treatment for Fever', 'State']

print(Malaria.shape)
Malaria.head()
# Out:
# (7745, 18)
#    Case Identification      Region Type of Place of Residence  \
# 0                 1002  north west                      urban
# 1                 1004  north west                      urban
# 2                 1007  north west                      urban
# 3                 1010  north west                      urban
# 4                 1013  north west                      urban
#
#   Source of Drinking Water                Type of Toilet Facility  \
# 0           protected well  ventilated improved pit latrine (vip)
# 1             tanker truck  ventilated improved pit latrine (vip)
# 2    tube well or borehole  ventilated improved pit latrine (vip)
# 3    tube well or borehole  ventilated improved pit latrine (vip)
# 4             tanker truck  ventilated improved pit latrine (vip)
#
#   Has Electricity Main Floor Material Main Wall Material Main Roof Material  \
# 0             yes              cement             cement         zinc/metal
# ...

# %%
#display malaria datatype of each column
Malaria.dtypes
# Out:
# Case Identification                     int64
# Region                                 object
# Type of Place of Residence             object
# Source of Drinking Water               object
# Type of Toilet Facility                object
# Has Electricity                        object
# Main Floor Material                    object
# Main Wall Material                     object
# Main Roof Material                     object
# Has Bicycle                            object
# Has Motorcycle or Scooter              object
# Has Car or Truck                       object
# Has Mosquito Bed Net for Sleeping      object
# Owns Land Suitable for Agriculture     object
# Has Bank Account                       object
# Wealth Index                           object
# Cost of Treatment for Fever           float64
# State                                  object
# dtype: object

# %%
# check for missing values
(Malaria.isnull()).any()
# Out:
# Case Identification                   False
# Region                                False
# Type of Place of Residence            False
# Source of Drinking Water              False
# Type of Toilet Facility                True
# Has Electricity                       False
# Main Floor Material                   False
# Main Wall Material                    False
# Main Roof Material                    False
# Has Bicycle                           False
# Has Motorcycle or Scooter             False
# Has Car or Truck                      False
# Has Mosquito Bed Net for Sleeping     False
# Owns Land Suitable for Agriculture    False
# Has Bank Account                      False
# Wealth Index                          False
# Cost of Treatment for Fever            True
# State                                 False
# dtype: bool

# %%
Malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7745 entries, 0 to 7744
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Case Identification                 7745 non-null   int64
#  1   Region                              7745 non-null   object
#  2   Type of Place of Residence          7745 non-null   object
#  3   Source of Drinking Water            7745 non-null   object
#  4   Type of Toilet Facility             7744 non-null   object
#  5   Has Electricity                     7745 non-null   object
#  6   Main Floor Material                 7745 non-null   object
#  7   Main Wall Material                  7745 non-null   object
#  8   Main Roof Material                  7745 non-null   object
#  9   Has Bicycle                         7745 non-null   object
#  10  Has Motorcycle or Scooter           7745 non-null   object
# ...

# %%
#Remove the column with missing values
Malaria.drop('Cost of Treatment for Fever', axis=1, inplace=True)

# %%
#
Malaria.dropna(inplace=True)

# %%
Malaria.to_csv('../Nigerian_malaria_dashboard.csv', index=False)

# %%
#check after removal 
Malaria.columns
# Out:
# Index(['Case Identification', 'Region', 'Type of Place of Residence',
#        'Source of Drinking Water', 'Type of Toilet Facility',
#        'Has Electricity', 'Main Floor Material', 'Main Wall Material',
#        'Main Roof Material', 'Has Bicycle', 'Has Motorcycle or Scooter',
#        'Has Car or Truck', 'Has Mosquito Bed Net for Sleeping',
#        'Owns Land Suitable for Agriculture', 'Has Bank Account',
#        'Wealth Index', 'State'],
#       dtype='object')

# %%
#
Malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7744 entries, 0 to 7744
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Case Identification                 7744 non-null   int64
#  1   Region                              7744 non-null   object
#  2   Type of Place of Residence          7744 non-null   object
#  3   Source of Drinking Water            7744 non-null   object
#  4   Type of Toilet Facility             7744 non-null   object
#  5   Has Electricity                     7744 non-null   object
#  6   Main Floor Material                 7744 non-null   object
#  7   Main Wall Material                  7744 non-null   object
#  8   Main Roof Material                  7744 non-null   object
#  9   Has Bicycle                         7744 non-null   object
#  10  Has Motorcycle or Scooter           7744 non-null   object
# ...

# %%
# Descriptive Statistic : case by States
Malaria['State'].value_counts()
# Out:
# State
# yobe             225
# jigawa           225
# bauchi           225
# gombe            225
# adamawa          225
# abia             225
# bayelsa          225
# lagos            225
# taraba           225
# cross river      225
# oyo              224
# sokoto           224
# ondo             223
# kebbi            222
# osun             221
# zamfara          220
# katsina          220
# ogun             220
# akwa ibom        220
# rivers           220
# kaduna           219
# enugu            217
# ekiti            217
# kano             216
# edo              211
# kogi             211
# benue            211
# niger            206
# ebonyi           201
# nasarawa         200
# plateau          196
# kwara            194
# imo              191
# delta            180
# anambra          168
# fct abuja        167
# borno - urban     75
# Name: count, dtype: int64

# %%
#to check electricity access
Malaria['Has Electricity'].value_counts()
# Out:
# Has Electricity
# yes    4247
# no     3497
# Name: count, dtype: int64

# %%
Malaria['Source of Drinking Water'].value_counts()
# Out:
# Source of Drinking Water
# tube well or borehole                                   2795
# river/dam/lake/ponds/stream/canal/irrigation channel     829
# unprotected well                                         819
# sachet water                                             786
# protected well                                           785
# public tap/standpipe                                     393
# unprotected spring                                       349
# rainwater                                                308
# piped into dwelling                                      238
# piped to yard/plot                                       101
# protected spring                                          87
# piped to neighbor                                         84
# tanker truck                                              71
# bottled water                                             68
# cart with small tank                                      27
# ...

# %%
Malaria['Wealth Index'].value_counts()
# Out:
# Wealth Index
# richer     1844
# richest    1816
# middle     1676
# poorer     1351
# poorest    1057
# Name: count, dtype: int64

# %%
Malaria['Has Mosquito Bed Net for Sleeping'].value_counts()
# Out:
# Has Mosquito Bed Net for Sleeping
# yes    5431
# no     2313
# Name: count, dtype: int64

# %%
Malaria.groupby('Wealth Index')['State'].describe()
# Out:
#              count unique       top freq
# Wealth Index
# middle        1676     37  nasarawa   89
# poorer        1351     35    taraba   97
# poorest       1057     25    sokoto  108
# richer        1844     37     ekiti  107
# richest       1816     36     lagos  207

# %%
Malaria.groupby("Has Bank Account")["State"].describe()
# Out:
#                  count unique     top freq
# Has Bank Account
# no                4476     37  jigawa  201
# yes               3268     37   lagos  177

# %%
#People having Mosquito bed by state
Malaria.groupby('Has Mosquito Bed Net for Sleeping')['State'].describe()
# Out:
#                                   count unique     top freq
# Has Mosquito Bed Net for Sleeping
# no                                 2313     37     edo  124
# yes                                5431     37  bauchi  221

# %%
Malaria.groupby('Has Electricity')['State'].describe()
# Out:
#                 count unique      top freq
# Has Electricity
# no               3497     37  adamawa  189
# yes              4247     37    lagos  224

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Pour chaque colonne de type object (catégorielle)
for col in Malaria.select_dtypes(include='object').columns:
    Malaria[col] = le.fit_transform(Malaria[col].astype(str))

# %%
Malaria.head()
# Out:
#    Case Identification  Region  Type of Place of Residence  \
# 0                 1002       2                           1
# 1                 1004       2                           1
# 2                 1007       2                           1
# 3                 1010       2                           1
# 4                 1013       2                           1
#
#    Source of Drinking Water  Type of Toilet Facility  Has Electricity  \
# 0                         7                       12                1
# 1                        12                       12                1
# 2                        13                       12                1
# 3                        13                       12                1
# 4                        12                       12                1
#
#    Main Floor Material  Main Wall Material  Main Roof Material  Has Bicycle  \
# 0                    1                   4                  13            0
# ...

# %%
Malaria.to_csv("../cleaned_data.csv", index=False)

# %%
Malaria.head()
# Out:
#    Case Identification  Region  Type of Place of Residence  \
# 0                 1002       2                           1
# 1                 1004       2                           1
# 2                 1007       2                           1
# 3                 1010       2                           1
# 4                 1013       2                           1
#
#    Source of Drinking Water  Type of Toilet Facility  Has Electricity  \
# 0                         7                       12                1
# 1                        12                       12                1
# 2                        13                       12                1
# 3                        13                       12                1
# 4                        12                       12                1
#
#    Main Floor Material  Main Wall Material  Main Roof Material  Has Bicycle  \
# 0                    1                   4                  13            0
# ...
